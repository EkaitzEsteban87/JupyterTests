# %% [raw]
# <script>
#   jQuery(document).ready(function($) {
#
#   $(window).on('load', function(){
#     $('#preloader').fadeOut('slow',function(){$(this).remove();});
#   });
#
#   });
# </script>
#
# <style type="text/css">
#   div#preloader { position: fixed;
#       left: 0;
#       top: 0;
#       z-index: 999;
#       width: 100%;
#       height: 100%;
#       overflow: visible;
#       background: #fff url('http://preloaders.net/preloaders/720/Moving%20line.gif') no-repeat center center;
#   }
#
# </style>
#
# <div id="preloader">
#
# </div>

# %% [raw]
# <script>
#   function code_toggle() {
#     if (code_shown){
#       $('div.input').hide('500');
#       $('#toggleButton').val('Show Code')
#     } else {
#       $('div.input').show('500');
#       $('#toggleButton').val('Hide Code')
#     }
#     code_shown = !code_shown
#   }
#
#   $( document ).ready(function(){
#     code_shown=false;
#     $('div.input').hide()
#   });
# </script>

# %% [markdown]
# <h1 style="text-align: center;" markdown="1">Mostrar graficos en 3D y sus proyecciones</h1>
#
# En esta pagina se muestran graficos en 3D y sus correspondientes proyecciones en 2D (falta realizarlos dinamicamente).

# %%
# Se puede crear "una base de datos de figuras en plotly y luego mostrarlos en jupyter"
import plotly.plotly as py
py.sign_in('Ekaitz', 'BDgvsvNlwdpp6anOtpSw')

fig = py.get_figure('https://plot.ly/~Ekaitz/4', raw=True)
py.iplot(fig)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~Ekaitz/14.embed" height="500px" width="500px"></iframe>

# %% [markdown]
# <h1 style="text-align: center;" markdown="1">Conclusiones</h1>
#
# Los resultados obtenidos son: bla bla bla...

# %% [raw]
# <script>
#   $(document).ready(function(){
#     $('div.prompt').hide();
#     $('div.back-to-top').hide();
#     $('nav#menubar').hide();
#     $('.breadcrumb').hide();
#     $('.hidden-print').hide();
#   });
# </script>
#
# <footer id="attribution" style="float:right; color:#999; background:#fff;">
# Created by PDSA.
# </footer>
